# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
crash_df = pd.read_csv("Datasets/Crash data_LA_county.csv")
harsh_acc_df = pd.read_csv("Datasets/Harsh Acceleration_Severity_Ranking_Clustering_LA_COUNTY_H10.csv")
harsh_brake_df = pd.read_csv("Datasets/Harsh Braking_Severity_Ranking_Clustering_LA_COUNTY_H10.csv")
poi_df = pd.read_csv("Datasets/POI Los Angeles County.csv")

# %%
crash_df.info()
crash_df = crash_df.dropna(inplace=True)
print(crash_df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 crash_df.info()
#       2 crash_df = crash_df.dropna(inplace=True)
#       3 print(crash_df.isnull().sum())
#
# NameError: name 'crash_df' is not defined

# %%
harsh_acc_df.info()
harsh_acc_df.dropna(inplace=True)
print(harsh_acc_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12868 entries, 0 to 12867
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLUSTER_ID                12868 non-null  int64
#  1   VEHICLE_COUNT             12868 non-null  int64
#  2   CENTROID                  12868 non-null  object
#  3   POLYGON                   12868 non-null  object
#  4   RANK                      12868 non-null  int64
#  5   MULTILINESTRING_CLUSTERS  12824 non-null  object
#  6   LENGTH_CLUSTER            12824 non-null  float64
#  7   LIST_ROAD_NAME            12868 non-null  object
#  8   LIST_CITY_NAME            12868 non-null  object
#  9   LIST_ROAD_PRIORITY        12868 non-null  object
#  10  H3_ID                     12868 non-null  object
#  11  H3_GEOM                   12868 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 1.2+ MB
# CLUSTER_ID                  0
# ...

# %%
harsh_brake_df.info()
harsh_brake_df.dropna(inplace=True)
print(harsh_brake_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLUSTER_ID                8768 non-null   int64
#  1   VEHICLE_COUNT             8768 non-null   int64
#  2   CENTROID                  8768 non-null   object
#  3   POLYGON                   8768 non-null   object
#  4   RANK                      8768 non-null   int64
#  5   MULTILINESTRING_CLUSTERS  8691 non-null   object
#  6   LENGTH_CLUSTER            8691 non-null   float64
#  7   LIST_ROAD_NAME            8768 non-null   object
#  8   LIST_CITY_NAME            8768 non-null   object
#  9   LIST_ROAD_PRIORITY        8768 non-null   object
#  10  H3_ID                     8768 non-null   object
#  11  H3_GEOM                   8768 non-null   object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 822.1+ KB
# CLUSTER_ID                  0
# ...

# %%
poi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55713 entries, 0 to 55712
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   point_id   55713 non-null  int64
#  1   longitude  55713 non-null  float64
#  2   latitude   55713 non-null  float64
#  3   location   55713 non-null  object
#  4   poi        55713 non-null  object
#  5   poi_type   55713 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.6+ MB
